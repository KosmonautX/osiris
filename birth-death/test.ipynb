# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xls = pd.ExcelFile("a.xls")
xls

df1 = pd.read_excel(xls, "T1 T2")

for index, row in df1.iterrows():
    print(row[1])

df1
# Out:
# nan
# Ethnic Group
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Note:
# nan
# nan
# nan
# nan
# nan
# Table  2 :    Vital Rates by Ethnic Group, 2015
# nan
# Ethnic Group
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37
#
# ...
